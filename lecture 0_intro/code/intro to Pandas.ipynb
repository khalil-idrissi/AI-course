# %% [markdown]
# # An introduction to pandas
# ***
# for more you should read the official documentation https://pandas.pydata.org/docs/
# ***

# %%
import pandas as pd

# %% [markdown]
# ***
# ## our data:

# %%
dt = {"name": ["khalil", "mohammed", "nezar"],
        "age": [22, 2, 4]}

# %% [markdown]
# ***
# ## to create a dataframe from a known dict:

# %%
df = pd.DataFrame(data=dt)

# %%
df
# Out:
#        name  age
# 0    khalil   22
# 1  mohammed    2
# 2     nezar    4

# %% [markdown]
# ***
# ## using the index argument to modify the index of the dataframe:

# %%
df = pd.DataFrame(data=dt, index=[1, 2, 3])

# %%
df
# Out:
#        name  age
# 1    khalil   22
# 2  mohammed    2
# 3     nezar    4

# %% [markdown]
# ***
# ## our data:

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8 ,9]]

# %% [markdown]
# ***
# ## create a dataframe a from known list:

# %%
dataframe = pd.DataFrame(data=data)

# %%
dataframe
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# ***
# ## changing column names:

# %%
dataframe = pd.DataFrame(data=data, columns=["a", "b", "c"])

# %%
dataframe
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df
# Out:
#        name  age
# 1    khalil   22
# 2  mohammed    2
# 3     nezar    4

# %% [markdown]
# ***
# ## some descriptive statistics about our data:

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean    9.333333
# std    11.015141
# min     2.000000
# 25%     3.000000
# 50%     4.000000
# 75%    13.000000
# max    22.000000

# %% [markdown]
# ***
# ## same as the previous cell but for a single column:

# %%
df["age"].describe()
# Out:
# count     3.000000
# mean      9.333333
# std      11.015141
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      13.000000
# max      22.000000
# Name: age, dtype: float64

# %% [markdown]
# ***
# ## read a csv file from a location:

# %%
dataframe = pd.read_csv(r"C:\Users\Desktop\club\lecture_0_intro\house_prediction_data\kc_house_data.csv")

# %%
dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ***
# ## show the first 5 rows:

# %%
dataframe.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ***
# ## show the first 10 rows:

# %%
dataframe.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# ***
# ## show the last 10 rows:

# %%
dataframe.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %% [markdown]
# ***
# ## show some useful infos about our dataframe:

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ***
# ## get the shape of our dataframe:

# %%
dataframe.shape
# Out:
# (21613, 20)

# %% [markdown]
# ***
# ## create a new dataframe from a known dataframe:

# %%
new_df = dataframe[["id", "floors"]]

# %%
new_df
# Out:
#                id  floors
# 0               1     1.0
# 1      6414100192     2.0
# 2      5631500400     1.0
# 3      2487200875     1.0
# 4      1954400510     1.0
# ...           ...     ...
# 21608   263000018     3.0
# 21609  6600060120     2.0
# 21610  1523300141     2.0
# 21611   291310100     2.0
# 21612  1523300157     2.0
#
# [21613 rows x 2 columns]

# %%
dataframe["price"]
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %% [markdown]
# ***
# ## filtering the data:

# %%
dataframe[dataframe["price"] > 400000]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %% [markdown]
# ***
# ## access the first row:

# %%
dataframe.iloc[0]
# Out:
# id                    7129300520
# date             20141013T000000
# price                   221900.0
# bedrooms                       3
# bathrooms                    1.0
# sqft_living                 1180
# sqft_lot                    5650
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1180
# sqft_basement                  0
# yr_built                    1955
# yr_renovated                   0
# zipcode                    98178
# lat                      47.5112
# long                    -122.257
# sqft_living15               1340
# sqft_lot15                  5650
# Name: 0, dtype: object

# %% [markdown]
# ***
# ## access the first 3 rows from row 0 to row 2:

# %%
dataframe.iloc[0:3]
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %% [markdown]
# ***
# ## changing the value for a cell:

# %%
dataframe["id"].iloc[0] = 1
# Out:
# C:\Users\monsi\anaconda3\envs\ai\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0               1  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ***
# ## more filtering:

# %%
dataframe.loc[dataframe["bedrooms"] > 5]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 209    6300000550  20140717T000000   464000.0         6       3.00
# 232    9264902050  20141121T000000   315000.0         6       2.75
# 239    5152100060  20140529T000000   472000.0         6       2.50
# 331    2946001550  20150416T000000   279000.0         6       1.75
# 486    9286000240  20140711T000000  1067000.0         6       3.50
# ...           ...              ...        ...       ...        ...
# 20984  2149800278  20141015T000000   343000.0         6       5.00
# 21085  4449800480  20150318T000000   677790.0         6       3.00
# 21186  7896300592  20150114T000000   303500.0         6       4.50
# 21375  6061500100  20140717T000000  1174660.0         6       3.50
# 21522   603000555  20150302T000000   462500.0         6       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 209           2300      3404     2.0           0     0  ...      7
# ...

# %% [markdown]
# ***
# ## deleting "date" column:

# %%
dataframe.drop(columns=["date"])
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0               1  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
dataframe = dataframe.drop(columns=["date"])

# %% [markdown]
# ***
# ## renaming column names:

# %%
dataframe.rename(columns={"id":"ids"})
# Out:
#               ids     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0               1  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# ***
# ## counting the frequency of values for a column:

# %%
dataframe["bedrooms"].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# ***
# ## checking if there is any N/A value:

# %%
dataframe.isnull().sum()
# Out:
# id               0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ***
# ## drop rows with N/A value

# %%
dataframe.dropna();

# %% [markdown]
# ***
# ## drop duplicate rows

# %%
dataframe.drop_duplicates();

# %% [markdown]
# ***
# ## replace N/A values with the value parameter

# %% [markdown]
# dataframe.fillna(value);
